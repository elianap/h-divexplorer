# %%
# %load_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import os
import pandas as pd
from divexplorer_generalized.FP_Divergence import FP_Divergence

# %% [markdown]
# # Import data

# %%
df = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-red.csv", sep=";")

df["quality"] = df["quality"].apply(lambda x: "good" if x>5 else "bad")
class_map = {'P': 'good', 'N': 'bad'}
df.rename(columns = {"quality": "class"}, inplace=True)

# %% [markdown]
# # Train and predict with RF classifier

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_predict
from sklearn.ensemble import RandomForestClassifier


attributes = df.columns.drop("class")
X = df[attributes].copy()
y = df["class"].copy()

clf = RandomForestClassifier(random_state=42)


k_cv = 10


cv = StratifiedKFold(n_splits=k_cv, random_state=42, shuffle=True
            )  # Added to fix the random state  #Added shuffle=True for new version sklearn, Value Error
       
y_predicted = cross_val_predict(clf, X, y.values, cv=cv)

# %%
df["predicted"] = y_predicted

# %%
df.shape[0]*0.03
# Out:
# 47.97

# %% [markdown]
# # Tree divergence

# %%
true_class_name = "class"
pred_class_name = "predicted"
cols_c = [true_class_name, pred_class_name]

# %%
continuous_attributes = list(df.describe().columns)

# %%
df_analyze = df.copy()

# %%
min_support_tree = 0.1

# %%
metric = "d_fpr"

# %%
type_criterion="divergence_criterion"

type_experiment = "one_at_time"

# %%
from tree_discretization import TreeDiscretization

tree_discr = TreeDiscretization()

# ## Extract tree
generalization_dict, discretizations = tree_discr.get_tree_discretization(
    df_analyze,
    type_splitting=type_experiment,
    min_support=min_support_tree,
    metric=metric,
    class_map=class_map,
    continuous_attributes=list(continuous_attributes),
    class_and_pred_names=cols_c,
    storeTree=True,
    type_criterion='entropy', #type_criterion,
    #minimal_gain = 0.0015
)

# %%
tree_discr.printDiscretizationTrees(round_v =2, show_condition = True)
# Out:
# fixed acidity
#  root s=1.00 --> d_fpr=0.00
#          fixed acidity<=10.1 s=0.85 --> d_fpr=-0.03
#                  fixed acidity<=6.5 s=0.10 --> d_fpr=0.08
#                  fixed acidity>6.5 s=0.75 --> d_fpr=-0.04
#                          fixed acidity<=7.0 s=0.12 --> d_fpr=-0.01
#                          fixed acidity>7.0 s=0.62 --> d_fpr=-0.05
#                                  fixed acidity<=7.7 s=0.22 --> d_fpr=-0.08
#                                          fixed acidity<=7.3 s=0.11 --> d_fpr=-0.09
#                                          fixed acidity>7.3 s=0.12 --> d_fpr=-0.08
#                                  fixed acidity>7.7 s=0.40 --> d_fpr=-0.03
#                                          fixed acidity<=8.5 s=0.18 --> d_fpr=0.00
#                                          fixed acidity>8.5 s=0.21 --> d_fpr=-0.06
#                                                  fixed acidity<=9.1 s=0.11 --> d_fpr=-0.11
#                                                  fixed acidity>9.1 s=0.11 --> d_fpr=-0.02
#          fixed acidity>10.1 s=0.15 --> d_fpr=0.30
#
# volatile acidity
#  root s=1.00 --> d_fpr=0.00
#          volatile acidity<=0.53 s=0.53 --> d_fpr=0.12
#                  volatile acidity<=0.31 s=0.11 --> d_fpr=0.44
#                  volatile acidity>0.31 s=0.42 --> d_fpr=0.09
#                          volatile acidity<=0.42 s=0.21 --> d_fpr=0.15
#                                  volatile acidity<=0.37 s=0.10 --> d_fpr=0.14
#                                  volatile acidity>0.37 s=0.11 --> d_fpr=0.16
#                          volatile acidity>0.42 s=0.21 --> d_fpr=0.04
#                                  volatile acidity<=0.48 s=0.10 --> d_fpr=0.03
#                                  volatile acidity>0.48 s=0.10 --> d_fpr=0.05
#          volatile acidity>0.53 s=0.47 --> d_fpr=-0.07
#                  volatile acidity<=0.68 s=0.30 --> d_fpr=-0.05
#                          volatile acidity<=0.605 s=0.16 --> d_fpr=-0.04
#                          volatile acidity>0.605 s=0.14 --> d_fpr=-0.06
#                  volatile acidity>0.68 s=0.17 --> d_fpr=-0.11
#
# citric acid
#  root s=1.00 --> d_fpr=0.00
#          citric acid<=0.27 s=0.53 --> d_fpr=-0.06
#                  citric acid<=0.12 s=0.30 --> d_fpr=-0.03
#                          citric acid<=0.04 s=0.17 --> d_fpr=-0.08
#                          citric acid>0.04 s=0.13 --> d_fpr=0.02
#                  citric acid>0.12 s=0.23 --> d_fpr=-0.08
#                          citric acid<=0.21 s=0.12 --> d_fpr=-0.12
#                          citric acid>0.21 s=0.12 --> d_fpr=-0.05
#          citric acid>0.27 s=0.47 --> d_fpr=0.10
#                  citric acid<=0.46 s=0.27 --> d_fpr=0.13
#                          citric acid<=0.34 s=0.11 --> d_fpr=0.05
#                          citric acid>0.34 s=0.15 --> d_fpr=0.21
#                  citric acid>0.46 s=0.20 --> d_fpr=0.06
#
# residual sugar
#  root s=1.00 --> d_fpr=0.00
#          residual sugar<=2.8 s=0.83 --> d_fpr=0.01
#                  residual sugar<=2.4 s=0.68 --> d_fpr=-0.01
#                          residual sugar<=1.9 s=0.29 --> d_fpr=-0.03
#                                  residual sugar<=1.75 s=0.14 --> d_fpr=-0.03
#                                  residual sugar>1.75 s=0.15 --> d_fpr=-0.04
#                          residual sugar>1.9 s=0.39 --> d_fpr=0.01
#                                  residual sugar<=2.2 s=0.26 --> d_fpr=0.03
#                                  residual sugar>2.2 s=0.12 --> d_fpr=-0.06
#                  residual sugar>2.4 s=0.16 --> d_fpr=0.11
#          residual sugar>2.8 s=0.17 --> d_fpr=-0.05
#
# chlorides
#  root s=1.00 --> d_fpr=0.00
#          chlorides<=0.067 s=0.20 --> d_fpr=0.20
#          chlorides>0.067 s=0.80 --> d_fpr=-0.03
#                  chlorides<=0.075 s=0.18 --> d_fpr=0.02
#                  chlorides>0.075 s=0.61 --> d_fpr=-0.04
#                          chlorides<=0.085 s=0.28 --> d_fpr=-0.07
#                                  chlorides<=0.079 s=0.12 --> d_fpr=-0.06
#                                  chlorides>0.079 s=0.16 --> d_fpr=-0.08
#                          chlorides>0.085 s=0.33 --> d_fpr=-0.02
#                                  chlorides<=0.092 s=0.11 --> d_fpr=0.04
#                                  chlorides>0.092 s=0.22 --> d_fpr=-0.04
#                                          chlorides<=0.106 s=0.12 --> d_fpr=-0.08
#                                          chlorides>0.106 s=0.11 --> d_fpr=-0.00
#
# free sulfur dioxide
#  root s=1.00 --> d_fpr=0.00
#          free sulfur dioxide<=9.0 s=0.33 --> d_fpr=0.08
#                  free sulfur dioxide<=5.0 s=0.12 --> d_fpr=0.05
#                  free sulfur dioxide>5.0 s=0.21 --> d_fpr=0.10
#          free sulfur dioxide>9.0 s=0.67 --> d_fpr=-0.04
#                  free sulfur dioxide<=29.0 s=0.56 --> d_fpr=-0.02
#                          free sulfur dioxide<=16.0 s=0.29 --> d_fpr=-0.04
#                                  free sulfur dioxide<=12.0 s=0.13 --> d_fpr=0.00
#                                  free sulfur dioxide>12.0 s=0.15 --> d_fpr=-0.08
#                          free sulfur dioxide>16.0 s=0.27 --> d_fpr=-0.01
#                                  free sulfur dioxide<=20.0 s=0.11 --> d_fpr=0.04
#                                  free sulfur dioxide>20.0 s=0.16 --> d_fpr=-0.03
#                  free sulfur dioxide>29.0 s=0.11 --> d_fpr=-0.09
#
# total sulfur dioxide
#  root s=1.00 --> d_fpr=0.00
#          total sulfur dioxide<=85.0 s=0.86 --> d_fpr=0.05
#                  total sulfur dioxide<=55.0 s=0.70 --> d_fpr=0.07
#                          total sulfur dioxide<=43.0 s=0.57 --> d_fpr=0.06
#                                  total sulfur dioxide<=31.0 s=0.42 --> d_fpr=0.08
#                                          total sulfur dioxide<=15.0 s=0.13 --> d_fpr=0.04
#                                          total sulfur dioxide>15.0 s=0.29 --> d_fpr=0.10
#                                                  total sulfur dioxide<=21.0 s=0.11 --> d_fpr=0.14
#                                                  total sulfur dioxide>21.0 s=0.18 --> d_fpr=0.08
#                                  total sulfur dioxide>31.0 s=0.15 --> d_fpr=0.01
#                          total sulfur dioxide>43.0 s=0.13 --> d_fpr=0.11
#                  total sulfur dioxide>55.0 s=0.16 --> d_fpr=-0.04
#          total sulfur dioxide>85.0 s=0.14 --> d_fpr=-0.16
#
# density
#  root s=1.00 --> d_fpr=0.00
#          density<=0.99522 s=0.18 --> d_fpr=0.22
#          density>0.99522 s=0.82 --> d_fpr=-0.02
#                  density<=0.99878 s=0.69 --> d_fpr=-0.04
#                          density<=0.99614 s=0.17 --> d_fpr=0.03
#                          density>0.99614 s=0.52 --> d_fpr=-0.05
#                                  density<=0.99675 s=0.15 --> d_fpr=-0.11
#                                  density>0.99675 s=0.37 --> d_fpr=-0.03
#                                          density<=0.99728 s=0.13 --> d_fpr=0.02
#                                          density>0.99728 s=0.24 --> d_fpr=-0.05
#                                                  density<=0.99785 s=0.12 --> d_fpr=-0.08
#                                                  density>0.99785 s=0.12 --> d_fpr=-0.02
#                  density>0.99878 s=0.13 --> d_fpr=0.05
#
# pH
#  root s=1.00 --> d_fpr=0.00
#          pH<=3.14 s=0.12 --> d_fpr=0.05
#          pH>3.14 s=0.88 --> d_fpr=-0.01
#                  pH<=3.21 s=0.14 --> d_fpr=-0.06
#                  pH>3.21 s=0.73 --> d_fpr=0.00
#                          pH<=3.26 s=0.11 --> d_fpr=0.05
#                          pH>3.26 s=0.62 --> d_fpr=-0.01
#                                  pH<=3.3 s=0.11 --> d_fpr=-0.06
#                                  pH>3.3 s=0.51 --> d_fpr=0.01
#                                          pH<=3.43 s=0.32 --> d_fpr=0.02
#                                                  pH<=3.38 s=0.22 --> d_fpr=-0.01
#                                                          pH<=3.34 s=0.10 --> d_fpr=0.01
#                                                          pH>3.34 s=0.11 --> d_fpr=-0.02
#                                                  pH>3.38 s=0.11 --> d_fpr=0.08
#                                          pH>3.43 s=0.19 --> d_fpr=-0.01
#
# sulphates
#  root s=1.00 --> d_fpr=0.00
#          sulphates<=0.55 s=0.26 --> d_fpr=-0.13
#                  sulphates<=0.51 s=0.13 --> d_fpr=-0.16
#                  sulphates>0.51 s=0.14 --> d_fpr=-0.09
#          sulphates>0.55 s=0.74 --> d_fpr=0.08
#                  sulphates<=0.59 s=0.15 --> d_fpr=0.03
#                  sulphates>0.59 s=0.59 --> d_fpr=0.11
#                          sulphates<=0.64 s=0.17 --> d_fpr=0.17
#                          sulphates>0.64 s=0.42 --> d_fpr=0.06
#                                  sulphates<=0.79 s=0.27 --> d_fpr=0.09
#                                          sulphates<=0.69 s=0.11 --> d_fpr=0.04
#                                          sulphates>0.69 s=0.16 --> d_fpr=0.14
#                                  sulphates>0.79 s=0.16 --> d_fpr=0.01
#
# alcohol
#  root s=1.00 --> d_fpr=0.00
#          alcohol<=10.1 s=0.50 --> d_fpr=-0.11
#                  alcohol<=9.5 s=0.27 --> d_fpr=-0.13
#                          alcohol<=9.3 s=0.12 --> d_fpr=-0.09
#                          alcohol>9.3 s=0.15 --> d_fpr=-0.16
#                  alcohol>9.5 s=0.23 --> d_fpr=-0.07
#                          alcohol<=9.8 s=0.12 --> d_fpr=-0.09
#                          alcohol>9.8 s=0.10 --> d_fpr=-0.04
#          alcohol>10.1 s=0.50 --> d_fpr=0.27
#                  alcohol<=11.3 s=0.31 --> d_fpr=0.21
#                          alcohol<=10.8 s=0.18 --> d_fpr=0.23
#                          alcohol>10.8 s=0.13 --> d_fpr=0.17
#                  alcohol>11.3 s=0.20 --> d_fpr=0.54

# %% [markdown]
# # Extract patterns

# %%
out_support = {}
out_time = {}

# %%
min_sup_divergences = [0.05]

# %% [markdown]
# ## Base

# %%
apply_generalization = False

if apply_generalization:
    type_gen = 'generalized'
else:
    type_gen = 'base'



from utils_extract_divergence_generalized import (
    extract_divergence_generalized,
)
import time

for min_sup_divergence in min_sup_divergences:
    s_time = time.time()
    FP_fm_base = extract_divergence_generalized(
        df_analyze,
        discretizations,
        generalization_dict,
        continuous_attributes,
        min_sup_divergence=min_sup_divergence,
        apply_generalization=False,
        true_class_name=true_class_name,
        predicted_class_name=pred_class_name,
        class_map=class_map,
        metrics_divergence = [metric],
        FPM_type="fpgrowth",
    )
    
    out_time.setdefault(min_sup_divergence, {})[type_gen] = time.time()-s_time
    fp_divergence_i_base = FP_Divergence(FP_fm_base, metric=metric)

    most_divergent_base = (
        fp_divergence_i_base.getDivergence(th_redundancy=0)
        .sort_values(
            [fp_divergence_i_base.metric, fp_divergence_i_base.t_value_col], ascending=False
        )
        .head(1)
    )
    out_support.setdefault(min_sup_divergence, {})[type_gen] = most_divergent_base

# %%
out_support[0.075]['base']
# Out:
#     support          itemsets  tn  fp  fn   tp  length  support_count  \
# 5  0.195122  (alcohol=>=11.4)  10  27   7  268       1          312.0
#
#        fpr     d_fpr  t_value_fp
# 5  0.72973  0.540214    7.268591

# %% [markdown]
# ## Generalized

# %%
from utils_extract_divergence_generalized import (
    extract_divergence_generalized,
)
import time

apply_generalization = True

if apply_generalization:
    type_gen = 'generalized'
else:
    type_gen = 'base'



#for min_sup_divergence in min_sup_divergences:
for min_sup_divergence in min_sup_divergences:
    s_time = time.time()
    FP_fm = extract_divergence_generalized(
        df_analyze,
        discretizations,
        generalization_dict,
        continuous_attributes,
        min_sup_divergence=min_sup_divergence,
        apply_generalization=apply_generalization,
        true_class_name=true_class_name,
        predicted_class_name=pred_class_name,
        class_map=class_map,
        metrics_divergence = [metric],
        FPM_type="fpgrowth",
        save_in_progress = False
    )
    
    out_time.setdefault(min_sup_divergence, {})[type_gen] = time.time()-s_time
    fp_divergence_i = FP_Divergence(FP_fm, metric=metric)

    most_divergent = (
        fp_divergence_i.getDivergence(th_redundancy=0)
        .sort_values(
            [fp_divergence_i.metric, fp_divergence_i.t_value_col], ascending=False
        )
        .head(1)
    )
    out_support.setdefault(min_sup_divergence, {})[type_gen] = most_divergent
# Out:
# 1 10000
# 2 20000
# 3 30000
# 4 40000
# 5 50000
# 6 60000
# 7 70000
# 8 80000
# 9 90000
# 10 100000
# 11 110000
# 12 120000
# 13 130000
# 14 140000
# 15 150000
# 16 160000
# 17 170000
# 18 180000
# 19 190000
# 20 200000
# 21 210000
# 22 220000
# 23 230000
# 24 240000
# 25 250000
# 26 260000
# 27 270000
# 28 280000
# 29 290000
# 30 300000
# 31 310000
# 32 320000
# 33 330000
# 34 340000
# 35 350000
# 36 360000
# 37 370000
# 38 380000
# 39 390000
# 40 400000
# 41 410000
# 42 420000
# 43 430000
# 44 440000
# 45 450000
# 46 460000
# 47 470000
# 48 480000
# 49 490000
# 50 500000
# 51 510000
# 52 520000
# 53 530000
# 54 540000
# 55 550000
# 56 560000
# 57 570000
# 58 580000
# 59 590000
# 60 600000
# 61 610000
# 62 620000
# 63 630000
# 64 640000
# 65 650000
# 66 660000
# 67 670000
# 68 680000
# 69 690000
# 70 700000
# 71 710000
# 72 720000
# 73 730000
# 74 740000
# 75 750000
# 76 760000
# 77 770000
# 78 780000
# 79 790000
# 80 800000
# 81 810000
# 82 820000
# 83 830000

# %% [markdown]
# # Results

# %%
out_time
# Out:
# {0.075: {'base': 0.3269538879394531, 'generalized': 70.16418313980103},
#  0.1: {'base': 0.25703001022338867, 'generalized': 33.832151889801025},
#  0.05: {'base': 1.0451099872589111, 'generalized': 266.29328632354736}}

# %%
for k in out_support:
    print(k)
    for t_gen in out_support[k]:
        print(t_gen)
        display(out_support[k][t_gen])
# Out:
# 0.075
# base
#     support          itemsets  tn  fp  fn   tp  length  support_count  \
# 5  0.195122  (alcohol=>=11.4)  10  27   7  268       1          312.0
#
#        fpr     d_fpr  t_value_fp
# 5  0.72973  0.540214    7.268591
# generalized
#         support                                           itemsets  tn  fp  \
# 70484  0.118199  (alcohol=>=10.2, total sulfur dioxide=<=85.0, ...   0  22
#
#        fn   tp  length  support_count  fpr     d_fpr  t_value_fp
# 70484   6  161       4          189.0  1.0  0.810484   18.083825
# 0.1
# base
#     support          itemsets  tn  fp  fn   tp  length  support_count  \
# 5  0.195122  (alcohol=>=11.4)  10  27   7  268       1          312.0
#
#        fpr     d_fpr  t_value_fp
# 5  0.72973  0.540214    7.268591
# generalized
#         support                                           itemsets  tn  fp  \
# 70094  0.118199  (alcohol=>=10.2, total sulfur dioxide=<=85.0, ...   0  22
#
#        fn   tp  length  support_count  fpr     d_fpr  t_value_fp
# 70094   6  161       4          189.0  1.0  0.810484   18.083825
# 0.05
# base
#       support                              itemsets  tn  fp  fn  tp  length  \
# 119  0.051907  (citric acid=>=0.47, alcohol=>=11.4)   0   6   1  76       2
#
#      support_count  fpr     d_fpr  t_value_fp
# 119           83.0  1.0  0.810484    6.158519
# generalized
#         support                                           itemsets  tn  fp  \
# 70528  0.118199  (alcohol=>=10.2, total sulfur dioxide=<=85.0, ...   0  22
#
#        fn   tp  length  support_count  fpr     d_fpr  t_value_fp
# 70528   6  161       4          189.0  1.0  0.810484   18.083825

# %%
462/60
